# %%
import requests
from atlassian import Confluence
import time
from getpass import getpass

contentApiUrl = '/rest/api/content'
# Change these based on your instance
confluenceBaseUrl = 'https://confluence.corp.bioagilytix.com/confluence'


def login():

    username = 'yangyang.liu'
    password = getpass("password")

# %%
##rest/api/space/{SPACE_KEY}/content?start=0&limit=9999&type=page
requestUrl = '{confluenceBaseUrl}{contentApiUrl}/{pageId}?expand=body.storage'.format(
    confluenceBaseUrl=confluenceBaseUrl, contentApiUrl=contentApiUrl, pageId=pageId)

spaceKey = "~yangyang.liu"
requestUrl = "https://confluence.corp.bioagilytix.com/confluence/rest/api/space/{SPACE_KEY}/content?start=0&limit=9999&type=page".format(
    SPACE_KEY=spaceKey)
print(requestUrl)

requestResponse = requests.get(requestUrl, auth=(username, password))

print(requestResponse.json())
# Out:
# https://confluence.corp.bioagilytix.com/confluence/rest/api/space/~yangyang.liu/content?start=0&limit=9999&type=page
# {'page': {'results': [{'id': '26908760', 'type': 'page', 'status': 'current', 'title': 'Yangyang Liu’s Home', 'extensions': {'position': 'none'}, '_links': {'webui': '/pages/viewpage.action?pageId=26908760', 'edit': '/pages/resumedraft.action?draftId=26908760', 'tinyui': '/x/WJiaAQ', 'self': 'https://confluence.corp.bioagilytix.com/confluence/rest/api/content/26908760'}, '_expandable': {'container': '/rest/api/space/~yangyang.liu', 'metadata': '', 'operations': '', 'children': '/rest/api/content/26908760/child', 'restrictions': '/rest/api/content/26908760/restriction/byOperation', 'history': '/rest/api/content/26908760/history', 'ancestors': '', 'body': '', 'version': '', 'descendants': '/rest/api/content/26908760/descendant', 'space': '/rest/api/space/~yangyang.liu'}}, {'id': '28607721', 'type': 'page', 'status': 'current', 'title': 'UMR 106 Cell Preparation for Assay_PTHrP_Method_Worksheet', 'extensions': {'position': 10}, '_links': {'webui': '/display/~yangyang.liu/UMR+106+Cell+Preparation+for+Assay_PTHrP_Method_Worksheet', 'edit': '/pages/resumedraft.action?draftId=28607721', 'tinyui': '/x/6YS0AQ', 'self': 'https://confluence.corp.bioagilytix.com/confluence/rest/api/content/28607721'}, '_expandable': {'container': '/rest/api/space/~yangyang.liu', 'metadata': '', 'operations': '', 'children': '/rest/api/content/28607721/child', 'restrictions': '/rest/api/content/28607721/restriction/byOperation', 'history': '/rest/api/content/28607721/history', 'ancestors': '', 'body': '', 'version': '', 'descendants': '/rest/api/content/28607721/descendant', 'space': '/rest/api/space/~yangyang.liu'}}, {'id': '28607722', 'type': 'page', 'status': 'current', 'title': 'Step 1   {26399829}', 'extensions': {'position': 0}, '_links': {'webui': '/pages/viewpage.action?pageId=28607722', 'edit': '/pages/resumedraft.action?draftId=28607722', 'tinyui': '/x/6oS0AQ', 'self': 'https://confluence.corp.bioagilytix.com/confluence/rest/api/content/28607722'}, '_expandable': {'container': '/rest/api/space/~yangyang.liu', 'metadata': '', 'operations': '', 'children': '/rest/api/content/28607722/child', 'restrictions': '/rest/api/content/28607722/restriction/byOperation', 'history': '/rest/api/content/28607722/history', 'ancestors': '', 'body': '', 'version': '', 'descendants': '/rest/api/content/28607722/descendant', 'space': '/rest/api/space/~yangyang.liu'}}, {'id': '28607723', 'type': 'page', 'status': 'current', 'title': 'Step 2   {26399829}', 'extensions': {'position': 1}, '_links': {'webui': '/pages/viewpage.action?pageId=28607723', 'edit': '/pages/resumedraft.action?draftId=28607723', 'tinyui': '/x/64S0AQ', 'self': 'https://confluence.corp.bioagilytix.com/confluence/rest/api/content/28607723'}, '_expandable': {'container': '/rest/api/space/~yangyang.liu', 'metadata': '', 'operations': '', 'children': '/rest/api/content/28607723/child', 'restrictions': '/rest/api/content/28607723/restriction/byOperation', 'history': '/rest/api/content/28607723/history', 'ancestors': '', 'body': '', 'version': '', 'descendants': '/rest/api/content/28607723/descendant', 'space': '/rest/api/space/~yangyang.liu'}}, {'id': '28607724', 'type': 'page', 'status': 'current', 'title': 'Step 3    {26399829}', 'extensions': {'position': 2}, '_links': {'webui': '/pages/viewpage.action?pageId=28607724', 'edit': '/pages/resumedraft.action?draftId=28607724', 'tinyui': '/x/7IS0AQ', 'self': 'https://confluence.corp.bioagilytix.com/confluence/rest/api/content/28607724'}, '_expandable': {'container': '/rest/api/space/~yangyang.liu', 'metadata': '', 'operations': '', 'children': '/rest/api/content/28607724/child', 'restrictions': '/rest/api/content/28607724/restriction/byOperation', 'history': '/rest/api/content/28607724/history', 'ancestors': '', 'body': '', 'version': '', 'descendants': '/rest/api/content/28607724/descendant', 'space': '/rest/api/space/~yangyang.liu'}}, {'id': '28607725', 'type': 'page', 'status': 'current', 'title': 'Step 4    {26399829}', 'extensions': {'position': 3}, ' ...

# %%
idList = list()
for page in requestResponse.json()['page']['results']:
    idList.append(page['id'])

# %%
for id in idList[0:5]:
    print(id)
# Out:
# 26908760
# 28607721
# 28607722
# 28607723
# 28607724

# %%
for id in idList[15:20]:
    spaceKey = "~yangyang.liu"

    requestUrl = "https://confluence.corp.bioagilytix.com/confluence/rest/scriptrunner/latest/custom/addFootNoteField?rootPageId={pageId}".format(pageId = id)
    print(requestUrl)

    requestResponse = requests.get(requestUrl, auth=(username, password))
    time.sleep(10)
    print(requestResponse.json())
# Out:
# https://confluence.corp.bioagilytix.com/confluence/rest/scriptrunner/latest/custom/addFootNoteField?rootPageId=28608001
# {'type': 'success', 'title': 'Execution Success', 'close': 'auto', 'body': 'Successfully updated Nothing! No Audit Form Found!.'}
# https://confluence.corp.bioagilytix.com/confluence/rest/scriptrunner/latest/custom/addFootNoteField?rootPageId=28608182
# {'type': 'success', 'title': 'Execution Success', 'close': 'auto', 'body': 'Successfully updated Run ID: 2 - Anti-PIT565 Screening Sample Analysis Assay in support of study 2070132.'}
# https://confluence.corp.bioagilytix.com/confluence/rest/scriptrunner/latest/custom/addFootNoteField?rootPageId=28608762
# {'type': 'success', 'title': 'Execution Success', 'close': 'auto', 'body': 'Successfully updated Nothing! No Audit Form Found!.'}
# https://confluence.corp.bioagilytix.com/confluence/rest/scriptrunner/latest/custom/addFootNoteField?rootPageId=28609560
# {'type': 'success', 'title': 'Execution Success', 'close': 'auto', 'body': 'Successfully updated Nothing! No Audit Form Found!.'}
# https://confluence.corp.bioagilytix.com/confluence/rest/scriptrunner/latest/custom/addFootNoteField?rootPageId=28610073
# {'type': 'success', 'title': 'Execution Success', 'close': 'auto', 'body': 'Successfully updated Nothing! No Audit Form Found!.'}

# %%
def isFinal(pageId):

    requestUrl = "https://confluence.corp.bioagilytix.com/confluence/rest/cw/1/content/{}/status".format(
        pageId)

    requestResponse = requests.get(requestUrl, auth=(username, password))
    if (requestResponse.status_code == 200):
        print(requestResponse.json())
        if requestResponse.json()['state']['name'] == "Final":
            return True
    return False

# %%
def isDraft(pageId):

    requestUrl = "https://confluence.corp.bioagilytix.com/confluence/rest/cw/1/content/{}/status".format(
        pageId)

    requestResponse = requests.get(requestUrl, auth=(username, password))
    if (requestResponse.status_code == 200):
        print(requestResponse.json())
        if requestResponse.json()['state']['name'] == "Draft":
            return True
    return False

# %%
pageId = "26385962"
requestUrl = "https://confluence.corp.bioagilytix.com/confluence/rest/cw/1/content/{}/status".format(
    pageId)

requestResponse = requests.get(requestUrl, auth=(username, password))
print(requestResponse.json())
# Out:
# {'expand': 'approvals,actions,tasks,states', 'workflowName': 'Developer-->Requestor-->QA Management Review', 'state': {'name': 'QA Management Review', 'initial': False, 'colour': '#4A6785', 'hideStates': False, 'taskable': True, 'changeDueDate': False, 'transitions': {'approved': {'state': 'Final'}, 'rejected': {'state': 'Developer Review'}, 'select': []}, 'final': False}, 'messages': [], 'displayProgressTracker': True, 'displaySuppressReadConfirmation': False, 'contributors': {'totalSize': -1, 'result': []}}
